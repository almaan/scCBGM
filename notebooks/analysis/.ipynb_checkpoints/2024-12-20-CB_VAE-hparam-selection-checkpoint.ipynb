# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
SRC_DIR = '../'
if SRC_DIR not in sys.path:
    sys.path.append(SRC_DIR)

# %%
import pandas as pd
import conceptlab as clab

# %%
entity, project = "rb-aiml", "clab_hparam_sweep"
df = clab.utils.wandb.download_wandb_project(project, entity)

# %%
df.head()
# Out:
#         model   modify  model.lr  model.beta  constants.seed  \
# 12396  cb_vae  default    0.0005      0.0001              13
# 12397  cb_vae  default    0.0005      0.0001              13
# 12398  cb_vae  default    0.0005      0.0001              13
# 12399  cb_vae  default    0.0005      0.0001              13
# 12400  cb_vae  default    0.0005      0.0001              13
#
#        model.hidden_dim  model.latent_dim  model.concepts_hp  \
# 12396               256                32              0.005
# 12397               256                32              0.005
# 12398               256                32              0.005
# 12399               256                32              0.005
# 12400               256                32              0.005
#
#        dataset.n_concepts  model.scale_concept  ...  use_soft_concepts  \
# 12396                  25                False  ...                NaN
# 12397                  25                False  ...                NaN
# 12398                  25                False  ...                NaN
# 12399                  25                False  ...                NaN
# 12400                  25                False  ...                NaN
#
#        independent_training  modularity_CEM_VAE_vs_true  \
# 12396                  True                         NaN
# 12397                  True                         NaN
# 12398                  True                         NaN
# 12399                  True                         NaN
# 12400                  True                         NaN
#
#        modularity_CEM_VAE_vs_vae_cbm_withGT  modularity_VAE_vs_true  \
# 12396                                   NaN                     NaN
# 12397                                   NaN                     NaN
# 12398                                   NaN                     NaN
# 12399                                   NaN                     NaN
# 12400                                   NaN                     NaN
#
#        modularity_CVAE_vs_true  has_condition  given_gt  \
# 12396                      NaN            NaN       NaN
# 12397                      NaN            NaN       NaN
# 12398                      NaN            NaN       NaN
# 12399                      NaN            NaN       NaN
# 12400                      NaN            NaN       NaN
#
#        modularity_CB_VAE_vs_true  modularity_CB_VAE_vs_vae_cbm_withGT
# 12396                   1.130672                             0.976063
# 12397                   1.096315                             0.944583
# 12398                   1.106464                             0.944393
# 12399                   1.121229                             0.967061
# 12400                   1.124664                             0.967261
#
# [5 rows x 69 columns]

# %%
df = df[df.model.values == 'cb_vae']

# %%
coi = ['AVG_ACC', 'test_MSE_loss','beta',
       'hidden_dim', 'latent_dim', 'n_concepts', 'min_bottleneck_size',
       'concepts_hp', 'orthogonality_hp','lr']

# %%
df_grouped = clab.utils.wandb.collapse_columns(df[coi], collapse_columns=['constants.seed', 'n_concepts','AVG_ACC', 'test_MSE_loss'])
# Out:
# ['beta', 'hidden_dim', 'latent_dim', 'min_bottleneck_size', 'concepts_hp', 'orthogonality_hp', 'lr']

# %%
top_models = clab.utils.wandb.find_top_models(df_grouped, target_columns=['AVG_ACC','test_MSE_loss'], target_direction=['max','min'])

# %%
top_models.sort_values('test_MSE_loss')
# Out:
#         beta  hidden_dim  latent_dim  min_bottleneck_size  concepts_hp  \
# 505  0.00010       256.0        64.0                128.0        0.005
# 193  0.00001       256.0        64.0                 64.0        0.005
# 195  0.00001       256.0        64.0                 64.0        0.005
# 197  0.00001       256.0        64.0                 64.0        0.005
# 243  0.00001       256.0       128.0                 64.0        0.005
# 245  0.00001       256.0       128.0                 64.0        0.005
#
#      orthogonality_hp      lr   AVG_ACC  test_MSE_loss  n_concepts
# 505               0.2  0.0005  0.814444       0.194241        50.0
# 193               0.2  0.0005  0.893889       0.194244        50.0
# 195               0.5  0.0005  0.896111       0.194662        50.0
# 197               1.0  0.0005  0.897222       0.194934        50.0
# 243               0.5  0.0005  0.902778       0.195083        50.0
# 245               1.0  0.0005  0.914444       0.195268        50.0

# %%
top_models.sort_values('test_MSE_loss').iloc[1]
# Out:
# beta                     0.000010
# hidden_dim             256.000000
# latent_dim              64.000000
# min_bottleneck_size     64.000000
# concepts_hp              0.005000
# orthogonality_hp         0.200000
# lr                       0.000500
# AVG_ACC                  0.893889
# test_MSE_loss            0.194244
# n_concepts              50.000000
# Name: 193, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.scatter(df_grouped['test_MSE_loss'], df_grouped['AVG_ACC'])
plt.scatter(top_models['test_MSE_loss'], top_models['AVG_ACC'], c  = 'orange')
plt.ylabel('AVG_ACC')
plt.xlabel('test_MSE_loss')
# Out:
# Text(0.5, 0, 'test_MSE_loss')
