# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
SRC_DIR = '../'
if SRC_DIR not in sys.path:
    sys.path.append(SRC_DIR)

# %%
import pandas as pd
import conceptlab as clab

# %%
entity, project = "rb-aiml", "clab_hparam_sweep"
df = clab.utils.wandb.download_wandb_project(project, entity)

# %%
df.head()
# Out:
#                 model   modify  model.lr  model.beta  constants.seed  \
# 0  skip_single_cb_vae  default     0.001     0.00001              13
# 1  skip_single_cb_vae  default     0.001     0.00001              13
# 2  skip_single_cb_vae  default     0.001     0.00001              13
# 3  skip_single_cb_vae  default     0.001     0.00001              13
# 4  skip_single_cb_vae  default     0.001     0.00001              13
#
#    model.hidden_dim  model.latent_dim  model.concepts_hp  dataset.n_concepts  \
# 0               256                32              0.005                  25
# 1               256                32              0.005                  25
# 2               256                32              0.005                  25
# 3               256                32              0.005                  25
# 4               256                32              0.005                  25
#
#    model.scale_concept  ...  use_soft_concepts  independent_training  \
# 0                False  ...              False                  True
# 1                False  ...              False                  True
# 2                False  ...              False                  True
# 3                False  ...              False                  True
# 4                False  ...              False                  True
#
#    modularity_CEM_VAE_vs_true  modularity_CEM_VAE_vs_vae_cbm_withGT  \
# 0                         NaN                                   NaN
# 1                         NaN                                   NaN
# 2                         NaN                                   NaN
# 3                         NaN                                   NaN
# 4                         NaN                                   NaN
#
#    modularity_VAE_vs_true  modularity_CVAE_vs_true  has_condition  given_gt  \
# 0                     NaN                      NaN            NaN       NaN
# 1                     NaN                      NaN            NaN       NaN
# 2                     NaN                      NaN            NaN       NaN
# 3                     NaN                      NaN            NaN       NaN
# 4                     NaN                      NaN            NaN       NaN
#
#    modularity_CB_VAE_vs_true  modularity_CB_VAE_vs_vae_cbm_withGT
# 0                        NaN                                  NaN
# 1                        NaN                                  NaN
# 2                        NaN                                  NaN
# 3                        NaN                                  NaN
# 4                        NaN                                  NaN
#
# [5 rows x 69 columns]

# %%
df = df[df.model.values == 'cvae']

# %%
coi = ['AVG_ACC', 'test_MSE_loss','beta',
       'hidden_dim', 'latent_dim', 'n_concepts','lr']

# %%
df_grouped = clab.utils.wandb.collapse_columns(df[coi], collapse_columns=['constants.seed', 'n_concepts','AVG_ACC', 'test_MSE_loss'])
# Out:
# ['beta', 'hidden_dim', 'latent_dim', 'lr']

# %%
top_models = clab.utils.wandb.find_top_models(df_grouped, target_columns=['AVG_ACC','test_MSE_loss'], target_direction=['max','min'])

# %%
top_models
# Out:
#        beta  hidden_dim  latent_dim      lr   AVG_ACC  test_MSE_loss  \
# 11  0.00001       256.0        32.0  0.0005  0.936111       0.193866
#
#     n_concepts
# 11        50.0

# %%
top_models.iloc[0]
# Out:
# beta               0.000010
# hidden_dim       256.000000
# latent_dim        32.000000
# lr                 0.000500
# AVG_ACC            0.936111
# test_MSE_loss      0.193866
# n_concepts        50.000000
# Name: 11, dtype: float64
