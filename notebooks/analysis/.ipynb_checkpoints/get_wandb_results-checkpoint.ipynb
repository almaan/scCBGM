# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import conceptlab as clab
import numpy as np

# %%
entity, project = "rb-aiml", "clab_hparam_sweep"
df = clab.utils.wandb.download_wandb_project(project, entity)

# %%
df['model'].value_counts()
# Out:
# model
# skip_single_cb_vae    8748
# cem_vae               3456
# cb_vae                3456
# vae                     96
# cvae                    96
# Name: count, dtype: int64

# %%
keep_models = ['skip_cb_vae', 'cem_vae', 'vae','cvae', 'cb_vae']

# %%
df = df.iloc[np.isin(df['model'].values, keep_models), :]

# %%
df.to_csv('../results/wandb_hparam_sweep.csv')
# Out:
#          model   modify  model.lr  model.beta  constants.seed  \
# 8748   cem_vae  default   0.00050     0.00010              13
# 8749   cem_vae  default   0.00050     0.00010              13
# 8750   cem_vae  default   0.00050     0.00010              13
# 8751   cem_vae  default   0.00050     0.00010              13
# 8752   cem_vae  default   0.00050     0.00010              13
# ...        ...      ...       ...         ...             ...
# 15847   cb_vae  default   0.00001     0.00001              42
# 15848   cb_vae  default   0.00001     0.00001              42
# 15849   cb_vae  default   0.00001     0.00001              42
# 15850   cb_vae  default   0.00001     0.00001              42
# 15851   cb_vae  default   0.00001     0.00001              42
#
#        model.hidden_dim  model.latent_dim  model.concepts_hp  \
# 8748                256                32              0.005
# 8749                256                32              0.005
# 8750                256                32              0.005
# 8751                256                32              0.005
# 8752                256                32              0.005
# ...                 ...               ...                ...
# 15847               128               128              0.500
# 15848               128               128              0.500
# 15849               128               128              0.500
# 15850               128               128              0.500
# 15851               128               128              0.500
#
#        dataset.n_concepts  model.scale_concept  ...  use_soft_concepts  \
# 8748                   25                False  ...                NaN
# 8749                   25                False  ...                NaN
# 8750                   25                False  ...                NaN
# 8751                   25                False  ...                NaN
# 8752                   25                False  ...                NaN
# ...                   ...                  ...  ...                ...
# 15847                  75                False  ...                NaN
# 15848                  75                False  ...                NaN
# 15849                  75                False  ...                NaN
# 15850                  75                False  ...                NaN
# 15851                  75                False  ...                NaN
#
#        independent_training  modularity_CEM_VAE_vs_true  \
# 8748                   True                    0.919407
# 8749                   True                    1.133054
# 8750                   True                    1.131793
# 8751                   True                    1.131757
# 8752                   True                    1.134803
# ...                     ...                         ...
# 15847                  True                         NaN
# 15848                  True                         NaN
# 15849                  True                         NaN
# 15850                  True                         NaN
# 15851                  True                         NaN
#
#        modularity_CEM_VAE_vs_vae_cbm_withGT  modularity_VAE_vs_true  \
# 8748                               0.961212                     NaN
# 8749                               0.955678                     NaN
# 8750                               0.965128                     NaN
# 8751                               0.980657                     NaN
# 8752                               0.981404                     NaN
# ...                                     ...                     ...
# 15847                                   NaN                     NaN
# 15848                                   NaN                     NaN
# 15849                                   NaN                     NaN
# 15850                                   NaN                     NaN
# 15851                                   NaN                     NaN
#
#        modularity_CVAE_vs_true  has_condition  given_gt  \
# 8748                       NaN            NaN       NaN
# 8749                       NaN            NaN       NaN
# 8750                       NaN            NaN       NaN
# 8751                       NaN            NaN       NaN
# 8752                       NaN            NaN       NaN
# ...                        ...            ...       ...
# 15847                      NaN            NaN       NaN
# 15848                      NaN            NaN       NaN
# 15849                      NaN            NaN       NaN
# 15850                      NaN            NaN       NaN
# 15851                      NaN            NaN       NaN
#
#        modularity_CB_VAE_vs_true  modularity_CB_VAE_vs_vae_cbm_withGT
# 8748                         NaN                                  NaN
# 8749                         NaN                                  NaN
# 8750                         NaN                                  NaN
# 8751                         NaN                                  NaN
# 8752                         NaN                                  NaN
# ...                          ...                                  ...
# 15847                   0.544798                             0.950614
# 15848                   0.543774                             0.947504
# 15849                   0.544143                             0.979641
# 15850                   0.543592                             0.976119
# 15851                   0.543471                             0.969239
#
# [7104 rows x 69 columns]
